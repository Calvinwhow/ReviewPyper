# %% [markdown]
# **This notebook is for analyzing EMR data only. If you are using academic articles, use notebooks OO_include_exclude_titles and 01_include_exclude_abstracts instead**

# %% [markdown]
# 00) Provide paths to the files you want to analyze and your desired output folder.

# %%
import pandas as pd
from calvin_utils.gpt_sys_review.txt_utils import ClinicalNotesExtractor


notes_file=['/Users/rm026/Documents/hbs_study_patient_notes/prg_test_file.txt',
            '/Users/rm026/Documents/hbs_study_patient_notes/dis_test_file.txt']
output_dir='/Users/rm026/Documents/hbs_study_patient_notes/testing_output_2/'

mrns_to_include=pd.read_csv('/Users/rm026/Documents/hbs_study_patient_notes/sub_id_to_mrn_included.csv')['MRN_primary'].values.tolist()

# %% [markdown]
# 01) Extract the data into new .txt files organized by MRN, and generate a master list to track them.

# %%
extractor=ClinicalNotesExtractor(notes_file, output_dir)
note_df=extractor.run(selected_mrns=mrns_to_include)
note_df
