# %%
import pandas as pd
from calvin_utils.gpt_sys_review.txt_utils import ClinicalNotesExtractor, ClinicalNotesOrganizer

myfile='/Users/rm026/Documents/hbs_study_patient_notes/dis_test_file.txt'
output_dir='/Users/rm026/Documents/hbs_study_patient_notes/testing_output/'
mymrns=pd.read_csv('/Users/rm026/Documents/hbs_study_patient_notes/sub_id_to_mrn_included.csv')['MRN_primary'].values.tolist()

# %%
extractor=ClinicalNotesExtractor.ClinicalNotesExtractor(myfile, output_dir)
note_df=extractor.run(selected_mrns=mymrns)
note_df
# Out:
# Master list saved to /Users/rm026/Documents/hbs_study_patient_notes/testing_output/master_list.csv
#         MRN                                           filepath
# 0   4302515  /Users/rm026/Documents/hbs_study_patient_notes...
# 1   4718619  /Users/rm026/Documents/hbs_study_patient_notes...
# 2   4950251  /Users/rm026/Documents/hbs_study_patient_notes...
# 3   4706803  /Users/rm026/Documents/hbs_study_patient_notes...
# 4   4937355  /Users/rm026/Documents/hbs_study_patient_notes...
# 5   4747083  /Users/rm026/Documents/hbs_study_patient_notes...
# 6   4366899  /Users/rm026/Documents/hbs_study_patient_notes...
# 7   4917131  /Users/rm026/Documents/hbs_study_patient_notes...
# 8   4819291  /Users/rm026/Documents/hbs_study_patient_notes...
# 9   4945539  /Users/rm026/Documents/hbs_study_patient_notes...
# 10  4970179  /Users/rm026/Documents/hbs_study_patient_notes...
# 11  4756571  /Users/rm026/Documents/hbs_study_patient_notes...
# ...
